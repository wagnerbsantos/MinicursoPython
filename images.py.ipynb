# %%
from scipy import misc
from PIL import Image
import numpy
im = numpy.asarray(Image.open("name.jpg"))
import matplotlib.pyplot as plt
plt.imshow(im)
plt.show()
im[0, 40] = numpy.array([255, 255, 255])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-40cd3a529b15> in <module>
#       6 plt.imshow(im)
#       7 plt.show()
# ----> 8 im[0, 40] = numpy.array([255, 255, 255])
#
# ValueError: assignment destination is read-only
